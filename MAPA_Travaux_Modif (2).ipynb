# %%
import pandas as pd 
import csv
import regex as re
import json

# %%
df = pd.read_csv('MAPA_Travaux.csv', encoding = 'utf-8', delimiter = ';')
# Out:
# C:\Users\couss\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (5,13) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df
# Out:
#             idweb annonce_reference_schema_v110  \
# 0        17-10008                           NaN
# 1        17-20008                           NaN
# 2        17-66902                           NaN
# 3        15-91869                           NaN
# 4       15-106209                           NaN
# ...           ...                           ...
# 144873  21-150007                           NaN
# 144874  21-150978                           NaN
# 144875  21-151940                           NaN
# 144876  21-157312                           NaN
# 144877  21-159270                           NaN
#
#                                                     objet famille  \
# 0       Réalisation d'un schéma directeur des systèmes...    MAPA
# 1       appel à candidaturesmarché de conception réali...    MAPA
# 2       MARCHE DE TRAVAUX RELATIF A L'AMENAGEMENT DE B...    MAPA
# 3       Entretien du réseau d'eaux pluviales de la vil...    MAPA
# 4                                 Travaux de désamiantage    MAPA
# ...                                                   ...     ...
# 144873  relance du lot plomberie, chauffage, vmc pour ...    MAPA
# 144874  TRAVAUX DE SIGNALISATION HORIZONTALE / MARQUAG...    MAPA
# 144875  RESTAURATION DES DÉCORS INTÉRIEURS DE L'EGLISE...    MAPA
# 144876  Aménagement des locaux Police municipale et Ba...    MAPA
# 144877  Création d'un espace associatif de convivialit...    MAPA
#
#        code_departement code_departement_prestation        famille_libelle  \
# 0                    56                         NaN  Marchés <90 k€ (MAPA)
# 1                    67                         NaN  Marchés <90 k€ (MAPA)
# 2                    75                         NaN  Marchés <90 k€ (MAPA)
# 3                    13                          13  Marchés <90 k€ (MAPA)
# 4                    93                          93  Marchés <90 k€ (MAPA)
# ...                 ...                         ...                    ...
# 144873               28                         NaN  Marchés <90 k€ (MAPA)
# 144874               13                         NaN  Marchés <90 k€ (MAPA)
# 144875    11,31,9,34,66                         NaN  Marchés <90 k€ (MAPA)
# 144876               37                         NaN  Marchés <90 k€ (MAPA)
# 144877               62                         NaN  Marchés <90 k€ (MAPA)
#
#        dateparution datefindiffusion          datelimitereponse  ...  \
# 0        2017-01-20       2017-02-20                        NaN  ...
# 1        2017-02-10       2017-03-06  2017-03-06T12:00:00+01:00  ...
# 2        2017-05-12       2017-06-10  2017-06-09T17:00:00+02:00  ...
# 3        2015-06-16       2015-07-28  2015-07-28T13:00:00+02:00  ...
# 4        2015-07-08       2015-07-20  2015-07-20T13:00:00+02:00  ...
# ...             ...              ...                        ...  ...
# 144873   2021-11-10       2021-12-02  2021-12-02T12:00:00+01:00  ...
# 144874   2021-11-15       2021-12-17  2021-12-17T12:00:00+01:00  ...
# 144875   2021-11-16       2021-12-16  2021-12-17T11:00:00+01:00  ...
# 144876   2021-11-29       2021-12-30  2021-12-30T23:00:00+01:00  ...
# 144877   2021-12-02       2022-01-10  2022-01-10T12:00:00+01:00  ...
#
#                                       descripteur_libelle       type_marche  \
# 0            Etude;Informatique (prestations de services)  SERVICES,TRAVAUX
# 1                                     Chauffage (travaux)  SERVICES,TRAVAUX
# 2                                   Electricité (travaux)  SERVICES,TRAVAUX
# 3                 Assainissement;Voirie et réseaux divers  SERVICES,TRAVAUX
# 4                                                 Amiante  SERVICES,TRAVAUX
# ...                                                   ...               ...
# 144873                                Plomberie (travaux)           TRAVAUX
# 144874                                      Signalisation           TRAVAUX
# 144875  Clocher;Décoration (travaux);Electricité (trav...           TRAVAUX
# 144876                                           Bâtiment           TRAVAUX
# 144877                                              Abris           TRAVAUX
#
#        type_marche_facette type_avis annonce_lie annonces_anterieures  \
# 0         Services,Travaux      5,1,         NaN                  NaN
# 1         Services,Travaux      5,1,         NaN                  NaN
# 2         Services,Travaux      5,1,         NaN                  NaN
# 3         Services,Travaux      5,1,         NaN                  NaN
# 4         Services,Travaux      5,1,         NaN                  NaN
# ...                    ...       ...         ...                  ...
# 144873             Travaux      5,1,         NaN                  NaN
# 144874             Travaux      5,1,         NaN                  NaN
# 144875             Travaux      5,1,         NaN                  NaN
# 144876             Travaux      5,1,         NaN                  NaN
# 144877             Travaux      5,1,         NaN                  NaN
#
#        annonces_anterieures_schema_v110   source_schema  \
# 0                                   NaN  Boamp_v230.xsd
# 1                                   NaN  Boamp_v230.xsd
# 2                                   NaN  Boamp_v230.xsd
# 3                                   NaN  Boamp_v230.xsd
# 4                                   NaN  Boamp_v230.xsd
# ...                                 ...             ...
# 144873                              NaN  Boamp_v230.xsd
# 144874                              NaN  Boamp_v230.xsd
# 144875                              NaN  Boamp_v230.xsd
# 144876                              NaN  Boamp_v230.xsd
# 144877                              NaN  Boamp_v230.xsd
#
#                                                   GESTION  \
# 0       {"INDEXATION": {"RESUME_OBJET": "Réalisation d...
# 1       {"INDEXATION": {"DATE_FIN_DIFFUSION": "2017-03...
# 2       {"INDEXATION": {"DATE_FIN_DIFFUSION": "2017-06...
# 3       {"INDEXATION": {"DATE_FIN_DIFFUSION": "2015-07...
# 4       {"INDEXATION": {"DATE_FIN_DIFFUSION": "2015-07...
# ...                                                   ...
# 144873  {"INDEXATION": {"DATE_FIN_DIFFUSION": "2021-12...
# 144874  {"INDEXATION": {"DATE_FIN_DIFFUSION": "2021-12...
# 144875  {"INDEXATION": {"DATE_FIN_DIFFUSION": "2021-12...
# 144876  {"INDEXATION": {"DATE_FIN_DIFFUSION": "2021-12...
# 144877  {"INDEXATION": {"DATE_FIN_DIFFUSION": "2022-01...
#
#                                                   DONNEES
# 0       {"OBJET": {"VARIANTES_NON": "", "LIEU_EXEC_LIV...
# 1       {"OBJET": {"OBJET_COMPLET": "Appel à candidatu...
# 2       {"OBJET": {"VARIANTES_OUI": "", "LIEU_EXEC_LIV...
# 3       {"OBJET": {"OBJET_COMPLET": "Entretien du rése...
# 4       {"OBJET": {"VARIANTES_NON": "", "LIEU_EXEC_LIV...
# ...                                                   ...
# 144873  {"OBJET": {"VARIANTES_NON": "", "LIEU_EXEC_LIV...
# 144874  {"OBJET": {"VARIANTES_NON": "", "LIEU_EXEC_LIV...
# 144875  {"OBJET": {"LOTS": {"LOT": [{"NUM": "1", "DESC...
# 144876  {"OBJET": {"LOTS": {"LOT": [{"NUM": "2", "DESC...
# 144877  {"OBJET": {"VARIANTES_NON": "", "LOTS": {"LOT"...
#
# [144878 rows x 37 columns]

# %%
df.columns
# Out:
# Index(['idweb', 'annonce_reference_schema_v110', 'objet', 'famille',
#        'code_departement', 'code_departement_prestation', 'famille_libelle',
#        'dateparution', 'datefindiffusion', 'datelimitereponse', 'nomacheteur',
#        'perimetre', 'type_procedure', 'soustype_procedure',
#        'procedure_libelle', 'procedure_categorise', 'nature', 'sousnature',
#        'nature_libelle', 'sousnature_libelle', 'nature_categorise',
#        'nature_categorise_libelle', 'criteres', 'marche_public_simplifie',
#        'marche_public_simplifie_label', 'etat', 'descripteur_code',
#        'descripteur_libelle', 'type_marche', 'type_marche_facette',
#        'type_avis', 'annonce_lie', 'annonces_anterieures',
#        'annonces_anterieures_schema_v110', 'source_schema', 'GESTION',
#        'DONNEES'],
#       dtype='object')

# %%
df['datefindiffusion'].unique()
# Out:
# array(['2017-02-20', '2017-03-06', '2017-06-10', ..., '2021-12-05',
#        '2022-01-08', '2021-12-02'], dtype=object)

# %%
# Tous les états sont en 'initial'
# annonce_lie a l'air pareil que idweb
df = df.drop(['annonce_reference_schema_v110','famille','soustype_procedure','procedure_libelle','procedure_categorise','sousnature'
              ,'sousnature_libelle','nature_categorise','nature_categorise_libelle',
             'marche_public_simplifie','marche_public_simplifie_label','type_marche_facette',
             'annonces_anterieures_schema_v110','source_schema'], axis=1)

# %%
df
# Out:
#             idweb                                              objet  \
# 0        17-10008  Réalisation d'un schéma directeur des systèmes...
# 1        17-20008  appel à candidaturesmarché de conception réali...
# 2        17-66902  MARCHE DE TRAVAUX RELATIF A L'AMENAGEMENT DE B...
# 3        15-91869  Entretien du réseau d'eaux pluviales de la vil...
# 4       15-106209                            Travaux de désamiantage
# ...           ...                                                ...
# 144873  21-150007  relance du lot plomberie, chauffage, vmc pour ...
# 144874  21-150978  TRAVAUX DE SIGNALISATION HORIZONTALE / MARQUAG...
# 144875  21-151940  RESTAURATION DES DÉCORS INTÉRIEURS DE L'EGLISE...
# 144876  21-157312  Aménagement des locaux Police municipale et Ba...
# 144877  21-159270  Création d'un espace associatif de convivialit...
#
#        code_departement code_departement_prestation        famille_libelle  \
# 0                    56                         NaN  Marchés <90 k€ (MAPA)
# 1                    67                         NaN  Marchés <90 k€ (MAPA)
# 2                    75                         NaN  Marchés <90 k€ (MAPA)
# 3                    13                          13  Marchés <90 k€ (MAPA)
# 4                    93                          93  Marchés <90 k€ (MAPA)
# ...                 ...                         ...                    ...
# 144873               28                         NaN  Marchés <90 k€ (MAPA)
# 144874               13                         NaN  Marchés <90 k€ (MAPA)
# 144875    11,31,9,34,66                         NaN  Marchés <90 k€ (MAPA)
# 144876               37                         NaN  Marchés <90 k€ (MAPA)
# 144877               62                         NaN  Marchés <90 k€ (MAPA)
#
#        dateparution datefindiffusion          datelimitereponse  \
# 0        2017-01-20       2017-02-20                        NaN
# 1        2017-02-10       2017-03-06  2017-03-06T12:00:00+01:00
# 2        2017-05-12       2017-06-10  2017-06-09T17:00:00+02:00
# 3        2015-06-16       2015-07-28  2015-07-28T13:00:00+02:00
# 4        2015-07-08       2015-07-20  2015-07-20T13:00:00+02:00
# ...             ...              ...                        ...
# 144873   2021-11-10       2021-12-02  2021-12-02T12:00:00+01:00
# 144874   2021-11-15       2021-12-17  2021-12-17T12:00:00+01:00
# 144875   2021-11-16       2021-12-16  2021-12-17T11:00:00+01:00
# 144876   2021-11-29       2021-12-30  2021-12-30T23:00:00+01:00
# 144877   2021-12-02       2022-01-10  2022-01-10T12:00:00+01:00
#
#                                 nomacheteur perimetre  ... criteres     etat  \
# 0                        Pontivy Communauté  CMP-2006  ...      NaN  INITIAL
# 1                                     Sibar  CMP-2006  ...      NaN  INITIAL
# 2          AGCE POUR L ENST FR A L ETRANGER  CMP-2006  ...      NaN  INITIAL
# 3                      Mairie de Pélissanne  CMP-2006  ...      NaN  INITIAL
# 4                        Université Paris 8  CMP-2006  ...      NaN  INITIAL
# ...                                     ...       ...  ...      ...      ...
# 144873    COMMUNE CLOYES LES TROIS RIVIERES  CMP-2006  ...      NaN  INITIAL
# 144874  COMMUNE DE SAINT MITRE LES REMPARTS  CMP-2006  ...      NaN  INITIAL
# 144875                   MAIRIE DE FANJEAUX  CMP-2006  ...      NaN  INITIAL
# 144876               Ville de Saint-Avertin  CMP-2006  ...      NaN  INITIAL
# 144877                    Mairie de Béthune  CMP-2006  ...      NaN  INITIAL
#
#              descripteur_code  \
# 0                     118,163
# 1                          61
# 2                         105
# 3                      18,366
# 4                          24
# ...                       ...
# 144873                    270
# 144874                    322
# 144875  80,85,105,195,264,308
# 144876                     33
# 144877                      1
#
#                                       descripteur_libelle       type_marche  \
# 0            Etude;Informatique (prestations de services)  SERVICES,TRAVAUX
# 1                                     Chauffage (travaux)  SERVICES,TRAVAUX
# 2                                   Electricité (travaux)  SERVICES,TRAVAUX
# 3                 Assainissement;Voirie et réseaux divers  SERVICES,TRAVAUX
# 4                                                 Amiante  SERVICES,TRAVAUX
# ...                                                   ...               ...
# 144873                                Plomberie (travaux)           TRAVAUX
# 144874                                      Signalisation           TRAVAUX
# 144875  Clocher;Décoration (travaux);Electricité (trav...           TRAVAUX
# 144876                                           Bâtiment           TRAVAUX
# 144877                                              Abris           TRAVAUX
#
#        type_avis annonce_lie annonces_anterieures  \
# 0           5,1,         NaN                  NaN
# 1           5,1,         NaN                  NaN
# 2           5,1,         NaN                  NaN
# 3           5,1,         NaN                  NaN
# 4           5,1,         NaN                  NaN
# ...          ...         ...                  ...
# 144873      5,1,         NaN                  NaN
# 144874      5,1,         NaN                  NaN
# 144875      5,1,         NaN                  NaN
# 144876      5,1,         NaN                  NaN
# 144877      5,1,         NaN                  NaN
#
#                                                   GESTION  \
# 0       {"INDEXATION": {"RESUME_OBJET": "Réalisation d...
# 1       {"INDEXATION": {"DATE_FIN_DIFFUSION": "2017-03...
# 2       {"INDEXATION": {"DATE_FIN_DIFFUSION": "2017-06...
# 3       {"INDEXATION": {"DATE_FIN_DIFFUSION": "2015-07...
# 4       {"INDEXATION": {"DATE_FIN_DIFFUSION": "2015-07...
# ...                                                   ...
# 144873  {"INDEXATION": {"DATE_FIN_DIFFUSION": "2021-12...
# 144874  {"INDEXATION": {"DATE_FIN_DIFFUSION": "2021-12...
# 144875  {"INDEXATION": {"DATE_FIN_DIFFUSION": "2021-12...
# 144876  {"INDEXATION": {"DATE_FIN_DIFFUSION": "2021-12...
# 144877  {"INDEXATION": {"DATE_FIN_DIFFUSION": "2022-01...
#
#                                                   DONNEES
# 0       {"OBJET": {"VARIANTES_NON": "", "LIEU_EXEC_LIV...
# 1       {"OBJET": {"OBJET_COMPLET": "Appel à candidatu...
# 2       {"OBJET": {"VARIANTES_OUI": "", "LIEU_EXEC_LIV...
# 3       {"OBJET": {"OBJET_COMPLET": "Entretien du rése...
# 4       {"OBJET": {"VARIANTES_NON": "", "LIEU_EXEC_LIV...
# ...                                                   ...
# 144873  {"OBJET": {"VARIANTES_NON": "", "LIEU_EXEC_LIV...
# 144874  {"OBJET": {"VARIANTES_NON": "", "LIEU_EXEC_LIV...
# 144875  {"OBJET": {"LOTS": {"LOT": [{"NUM": "1", "DESC...
# 144876  {"OBJET": {"LOTS": {"LOT": [{"NUM": "2", "DESC...
# 144877  {"OBJET": {"VARIANTES_NON": "", "LOTS": {"LOT"...
#
# [144878 rows x 23 columns]

# %%
first_line = df['DONNEES'][0]
first_line
# Out:
# '{"OBJET": {"VARIANTES_NON": "", "LIEU_EXEC_LIVR": {"VILLE": "Pontivy", "CP": "56300", "ADRESSE": "Territoire de pontivy communauté"}, "OBJET_COMPLET": "Réalisation d\'un schéma directeur des systèmes d\'information intercommunal", "DIV_EN_LOTS": {"NON": ""}, "CARACTERISTIQUES": {"QUANTITE": "Réalisation d\'un schéma directeur des systèmes d\'information intercommunal", "PRINCIPALES": "Délai d\'exécution : 36 mois Variantes non autorisées.Accord-cadre à bons de commande et à tranche optionnelle. Marché à prix mixtes : forfaitaires et unitaires à bons de commande.Pontivy Communauté figurant au titre des pilotes du projet national 100% demat des marchés publics, conformément à l\'article 40 du Décret 2016-360, la collectivité impose pour ce marché le mode de transmission des offres par voie électronique notamment via le dispositif MPS permettant de réduire les informations à transmettre. Ce marché fait partie du dispositif \\" marché public simplifié \\" (MPS) dans le cadre du programme national \\" Dites-le-nous une fois \\". La réponse papier ne sera pas acceptée."}, "TYPE_MARCHE": {"TRAVAUX": "", "SERVICE": ""}}, "IDENTITE": {"VILLE": "Pontivy cédex", "FAX": "02-97-25-63-69", "TEL": "02-97-25-01-70", "URL": "http://marches.megalisbretagne.org", "MEL": "marchespublics@pontivy-communaute.bzh", "ADRESSE": "1 Place Ernest Jan - bp96", "CORRESPONDANT": "Mme BROHAN Laëtitia, Service marchés publics", "CP": "56303", "DENOMINATION": "Pontivy Communauté"}, "RENSEIGNEMENTS_COMPLEMENTAIRES": {"RENS_COMPLEMENT": "Le dossier pourra être retiré gratuitement sur la plateforme megalis bretagne en suivant le lien de dématérialisation suivant: https://marches.e-megalisbretagne.org/. No de référence attribué au marché à indiquer pour une recherche rapide sur la plateforme Megalis: PI2017-01-02Les candidats ont la faculté de présenter leur offre uniquement sous forme dématérialisée classique ou avec le dispositif MPS (avec ou sans signature). Par contre, les candidats doivent choisir un seul mode de transmission de leur offre, soit par voie électronique, soit par le dispositif MPS, sous peine du rejet de l\'offre.Pour une remise des offres dématérialisée classique : utiliser la plateforme mégalis bretagne sous le lien https://marches.emegalisbretagne.org/ et rappeler le no de référence attribué au marché:Pi2017-01-02Ce marché est conforme au dispositif d\'expérimentation MPS (Marché Public Simplifié), et permet aux entreprises de candidater sur la base de leur seul numéro de SIRET. Le modede transmission des éléments de la candidature et de l\'offre est dématérialisé. La réponse électronique est indispensable mais aucune signature n\'est exigée (La signature sera dans ce cas demandée a posteriori à la seule entreprise retenue). Voir les détails dans le règlement de la consultation", "ADRESSES_COMPLEMENTAIRES": {"ADRESSE": {"URL": "https://marches.e-megalisbretagne.org", "TYPE": {"DOCUMENTS": ""}, "DENOMINATION": "Site de Mégalis Bretagne avec la référence PI2017-01-02"}}}, "CONDITION_PARTICIPATION": {"ELIGIBLE_MPS": {"oui": ""}}, "CONDITION_ADMINISTRATIVE": {"REFERENCE_MARCHE": "PI2017-01-02"}, "CONDITION_RELATIVE_MARCHE": {"FINANCEMENT": "Ressouces propres et subventions auxquelles la collectivité peut prétendre"}, "TYPE_ORGANISME": {"EPT": ""}, "PROCEDURE": {"TYPE_PROCEDURE": {"PROCEDURE_ADAPTE": ""}, "CRITERES_ATTRIBUTION": {"CRITERES_PONDERES": {"CRITERE": [{"#text": "Prix des prestations", "@POIDS": "60"}, {"#text": "Valeur technique", "@POIDS": "40"}]}}}}'

# %%
# On enlève le objet et les {} (au début et à la fin) car inutile
first_line = first_line.replace('{"OBJET": ','')
first_line=first_line[:-1]

# %%
import re
# on sépare les éléments en fonction de {} 
# pour commencer à voir les différents dictionnaires et clés/valeures
first_line = re.split('[{}]', first_line)
first_line
# Out:
# ['',
#  '"VARIANTES_NON": "", "LIEU_EXEC_LIVR": ',
#  '"VILLE": "Pontivy", "CP": "56300", "ADRESSE": "Territoire de pontivy communauté"',
#  ', "OBJET_COMPLET": "Réalisation d\'un schéma directeur des systèmes d\'information intercommunal", "DIV_EN_LOTS": ',
#  '"NON": ""',
#  ', "CARACTERISTIQUES": ',
#  '"QUANTITE": "Réalisation d\'un schéma directeur des systèmes d\'information intercommunal", "PRINCIPALES": "Délai d\'exécution : 36 mois Variantes non autorisées.Accord-cadre à bons de commande et à tranche optionnelle. Marché à prix mixtes : forfaitaires et unitaires à bons de commande.Pontivy Communauté figurant au titre des pilotes du projet national 100% demat des marchés publics, conformément à l\'article 40 du Décret 2016-360, la collectivité impose pour ce marché le mode de transmission des offres par voie électronique notamment via le dispositif MPS permettant de réduire les informations à transmettre. Ce marché fait partie du dispositif \\" marché public simplifié \\" (MPS) dans le cadre du programme national \\" Dites-le-nous une fois \\". La réponse papier ne sera pas acceptée."',
#  ', "TYPE_MARCHE": ',
#  '"TRAVAUX": "", "SERVICE": ""',
#  '',
#  ', "IDENTITE": ',
#  '"VILLE": "Pontivy cédex", "FAX": "02-97-25-63-69", "TEL": "02-97-25-01-70", "URL": "http://marches.megalisbretagne.org", "MEL": "marchespublics@pontivy-communaute.bzh", "ADRESSE": "1 Place Ernest Jan - bp96", "CORRESPONDANT": "Mme BROHAN Laëtitia, Service marchés publics", "CP": "56303", "DENOMINATION": "Pontivy Communauté"',
#  ', "RENSEIGNEMENTS_COMPLEMENTAIRES": ',
#  '"RENS_COMPLEMENT": "Le dossier pourra être retiré gratuitement sur la plateforme megalis bretagne en suivant le lien de dématérialisation suivant: https://marches.e-megalisbretagne.org/. No de référence attribué au marché à indiquer pour une recherche rapide sur la plateforme Megalis: PI2017-01-02Les candidats ont la faculté de présenter leur offre uniquement sous forme dématérialisée classique ou avec le dispositif MPS (avec ou sans signature). Par contre, les candidats doivent choisir un seul mode de transmission de leur offre, soit par voie électronique, soit par le dispositif MPS, sous peine du rejet de l\'offre.Pour une remise des offres dématérialisée classique : utiliser la plateforme mégalis bretagne sous le lien https://marches.emegalisbretagne.org/ et rappeler le no de référence attribué au marché:Pi2017-01-02Ce marché est conforme au dispositif d\'expérimentation MPS (Marché Public Simplifié), et permet aux entreprises de candidater sur la base de leur seul numéro de SIRET. Le modede transmission des éléments de la candidature et de l\'offre est dématérialisé. La réponse électronique est indispensable mais aucune signature n\'est exigée (La signature sera dans ce cas demandée a posteriori à la seule entreprise retenue). Voir les détails dans le règlement de la consultation", "ADRESSES_COMPLEMENTAIRES": ',
#  '"ADRESSE": ',
#  '"URL": "https://marches.e-megalisbretagne.org", "TYPE": ',
#  '"DOCUMENTS": ""',
#  ', "DENOMINATION": "Site de Mégalis Bretagne avec la référence PI2017-01-02"',
#  '',
#  '',
#  ', "CONDITION_PARTICIPATION": ',
#  '"ELIGIBLE_MPS": ',
#  '"oui": ""',
#  '',
#  ', "CONDITION_ADMINISTRATIVE": ',
#  '"REFERENCE_MARCHE": "PI2017-01-02"',
#  ', "CONDITION_RELATIVE_MARCHE": ',
#  '"FINANCEMENT": "Ressouces propres et subventions auxquelles la collectivité peut prétendre"',
#  ', "TYPE_ORGANISME": ',
#  '"EPT": ""',
#  ', "PROCEDURE": ',
#  '"TYPE_PROCEDURE": ',
#  '"PROCEDURE_ADAPTE": ""',
#  ', "CRITERES_ATTRIBUTION": ',
#  '"CRITERES_PONDERES": ',
#  '"CRITERE": [',
#  '"#text": "Prix des prestations", "@POIDS": "60"',
#  ', ',
#  '"#text": "Valeur technique", "@POIDS": "40"',
#  ']',
#  '',
#  '',
#  '']

# %%
#on va enlever les éléments vides/ sans infos
for elm in first_line:
    if not re.search(':("|\s")',elm):
        print(elm)
        first_line.remove(elm)
# Out:
# , "CARACTERISTIQUES":
# , "TYPE_MARCHE":
#
# , "RENSEIGNEMENTS_COMPLEMENTAIRES":
# "ADRESSE":
#
# , "CONDITION_PARTICIPATION":
#
# , "CONDITION_RELATIVE_MARCHE":
# , "TYPE_ORGANISME":
# , "PROCEDURE":
# , "CRITERES_ATTRIBUTION":
# "CRITERE": [
# ,
# ]

# %%
# si un élément a plusieurs clés valeurs mais que l'element se termine par ':' on ajoute ""
for i in range(len(first_line)):
    elm_bis = first_line[i].split(",")
    temp=""
    for micro_elm in elm_bis:
        if re.search(':',micro_elm) and (not re.search(':("|\s)',micro_elm) and (': [' not in micro_elm)):
            print("micro : ",micro_elm)
            micro_elm += '""'
            print("micro change: ",micro_elm)
            temp+= micro_elm+","
        elif not re.search(':|"',micro_elm):
            temp+= micro_elm+ " "
        else:
            temp+= micro_elm+","            
    temp = temp[:-1] # on enlève la dernière virgule
    first_line[i] =  temp

# %%
first_line
# Out:
# ['"VARIANTES_NON": "", "LIEU_EXEC_LIVR": ',
#  '"VILLE": "Pontivy", "CP": "56300", "ADRESSE": "Territoire de pontivy communauté"',
#  '  "OBJET_COMPLET": "Réalisation d\'un schéma directeur des systèmes d\'information intercommunal", "DIV_EN_LOTS": ',
#  '"NON": ""',
#  '"QUANTITE": "Réalisation d\'un schéma directeur des systèmes d\'information intercommunal", "PRINCIPALES": "Délai d\'exécution : 36 mois Variantes non autorisées.Accord-cadre à bons de commande et à tranche optionnelle. Marché à prix mixtes : forfaitaires et unitaires à bons de commande.Pontivy Communauté figurant au titre des pilotes du projet national 100% demat des marchés publics, conformément à l\'article 40 du Décret 2016-360  la collectivité impose pour ce marché le mode de transmission des offres par voie électronique notamment via le dispositif MPS permettant de réduire les informations à transmettre. Ce marché fait partie du dispositif \\" marché public simplifié \\" (MPS) dans le cadre du programme national \\" Dites-le-nous une fois \\". La réponse papier ne sera pas acceptée."',
#  '"TRAVAUX": "", "SERVICE": ""',
#  '  "IDENTITE": ',
#  '"VILLE": "Pontivy cédex", "FAX": "02-97-25-63-69", "TEL": "02-97-25-01-70", "URL": "http://marches.megalisbretagne.org", "MEL": "marchespublics@pontivy-communaute.bzh", "ADRESSE": "1 Place Ernest Jan - bp96", "CORRESPONDANT": "Mme BROHAN Laëtitia, Service marchés publics", "CP": "56303", "DENOMINATION": "Pontivy Communauté"',
#  '"RENS_COMPLEMENT": "Le dossier pourra être retiré gratuitement sur la plateforme megalis bretagne en suivant le lien de dématérialisation suivant: https://marches.e-megalisbretagne.org/. No de référence attribué au marché à indiquer pour une recherche rapide sur la plateforme Megalis: PI2017-01-02Les candidats ont la faculté de présenter leur offre uniquement sous forme dématérialisée classique ou avec le dispositif MPS (avec ou sans signature). Par contre, les candidats doivent choisir un seul mode de transmission de leur offre  soit par voie électronique  soit par le dispositif MPS  sous peine du rejet de l\'offre.Pour une remise des offres dématérialisée classique : utiliser la plateforme mégalis bretagne sous le lien https://marches.emegalisbretagne.org/ et rappeler le no de référence attribué au marché:Pi2017-01-02Ce marché est conforme au dispositif d\'expérimentation MPS (Marché Public Simplifié), et permet aux entreprises de candidater sur la base de leur seul numéro de SIRET. Le modede transmission des éléments de la candidature et de l\'offre est dématérialisé. La réponse électronique est indispensable mais aucune signature n\'est exigée (La signature sera dans ce cas demandée a posteriori à la seule entreprise retenue). Voir les détails dans le règlement de la consultation", "ADRESSES_COMPLEMENTAIRES": ',
#  '"URL": "https://marches.e-megalisbretagne.org", "TYPE": ',
#  '"DOCUMENTS": ""',
#  '  "DENOMINATION": "Site de Mégalis Bretagne avec la référence PI2017-01-02"',
#  '"ELIGIBLE_MPS": ',
#  '"oui": ""',
#  '  "CONDITION_ADMINISTRATIVE": ',
#  '"REFERENCE_MARCHE": "PI2017-01-02"',
#  '"FINANCEMENT": "Ressouces propres et subventions auxquelles la collectivité peut prétendre"',
#  '"EPT": ""',
#  '"TYPE_PROCEDURE": ',
#  '"PROCEDURE_ADAPTE": ""',
#  '"CRITERES_PONDERES": ',
#  '"#text": "Prix des prestations", "@POIDS": "60"',
#  '"#text": "Valeur technique", "@POIDS": "40"',
#  '',
#  '',
#  '']

# %%
dictio ={}
for elm in first_line:
    for elm_bis in elm.split(',', elm.count(": ")- elm.count("adresse suivante")):
        try:
            cle_val =elm_bis.split(': ')
            cle_dictio= re.sub('"','',cle_val[0])
            if cle_dictio.upper() == cle_dictio:
                cle_dictio = re.sub(' ','',cle_dictio)
            val_dictio = re.sub('"','',' '.join(cle_val[1:]))
            dictio[cle_dictio] = val_dictio
        except:
            print(elm_bis)
            print(elm_bis.split(':'))

# %%
dictio
# Out:
# {'VARIANTES_NON': '',
#  'LIEU_EXEC_LIVR': '',
#  'VILLE': 'Pontivy cédex',
#  'CP': '56303',
#  'ADRESSE': '1 Place Ernest Jan - bp96',
#  'OBJET_COMPLET': "Réalisation d'un schéma directeur des systèmes d'information intercommunal",
#  'DIV_EN_LOTS': '',
#  'NON': '',
#  'QUANTITE': "Réalisation d'un schéma directeur des systèmes d'information intercommunal",
#  'PRINCIPALES': "Délai d'exécution  36 mois Variantes non autorisées.Accord-cadre à bons de commande et à tranche optionnelle. Marché à prix mixtes  forfaitaires et unitaires à bons de commande.Pontivy Communauté figurant au titre des pilotes du projet national 100% demat des marchés publics",
#  " conformément à l'article 40 du Décret 2016-360  la collectivité impose pour ce marché le mode de transmission des offres par voie électronique notamment via le dispositif MPS permettant de réduire les informations à transmettre. Ce marché fait partie du dispositif \\ marché public simplifié \\ (MPS) dans le cadre du programme national \\ Dites-le-nous une fois \\. La réponse papier ne sera pas acceptée.": '',
#  'TRAVAUX': '',
#  'SERVICE': '',
#  'IDENTITE': '',
#  'FAX': '02-97-25-63-69',
#  'TEL': '02-97-25-01-70',
#  'URL': 'https://marches.e-megalisbretagne.org',
#  'MEL': 'marchespublics@pontivy-communaute.bzh',
#  'CORRESPONDANT': 'Mme BROHAN Laëtitia',
#  ' Service marchés publics': '',
#  'DENOMINATION': 'Site de Mégalis Bretagne avec la référence PI2017-01-02',
#  'RENS_COMPLEMENT': 'Le dossier pourra être retiré gratuitement sur la plateforme megalis bretagne en suivant le lien de dématérialisation suivant https://marches.e-megalisbretagne.org/. No de référence attribué au marché à indiquer pour une recherche rapide sur la plateforme Megalis PI2017-01-02Les candidats ont la faculté de présenter leur offre uniquement sous forme dématérialisée classique ou avec le dispositif MPS (avec ou sans signature). Par contre',
#  " les candidats doivent choisir un seul mode de transmission de leur offre  soit par voie électronique  soit par le dispositif MPS  sous peine du rejet de l'offre.Pour une remise des offres dématérialisée classique ": "utiliser la plateforme mégalis bretagne sous le lien https://marches.emegalisbretagne.org/ et rappeler le no de référence attribué au marché:Pi2017-01-02Ce marché est conforme au dispositif d'expérimentation MPS (Marché Public Simplifié)",
#  " et permet aux entreprises de candidater sur la base de leur seul numéro de SIRET. Le modede transmission des éléments de la candidature et de l'offre est dématérialisé. La réponse électronique est indispensable mais aucune signature n'est exigée (La signature sera dans ce cas demandée a posteriori à la seule entreprise retenue). Voir les détails dans le règlement de la consultation": '',
#  'ADRESSES_COMPLEMENTAIRES': '',
#  'TYPE': '',
#  'DOCUMENTS': '',
#  'ELIGIBLE_MPS': '',
#  'oui': '',
#  'CONDITION_ADMINISTRATIVE': '',
#  'REFERENCE_MARCHE': 'PI2017-01-02',
#  'FINANCEMENT': 'Ressouces propres et subventions auxquelles la collectivité peut prétendre',
#  'EPT': '',
#  'TYPE_PROCEDURE': '',
#  'PROCEDURE_ADAPTE': '',
#  'CRITERES_PONDERES': '',
#  '#text': 'Valeur technique',
#  '@POIDS': '40',
#  '': ''}

# %%
print(len(dictio.keys()))
dictio.keys()
# Out:
# 39
# dict_keys(['VARIANTES_NON', 'LIEU_EXEC_LIVR', 'VILLE', 'CP', 'ADRESSE', 'OBJET_COMPLET', 'DIV_EN_LOTS', 'NON', 'QUANTITE', 'PRINCIPALES', " conformément à l'article 40 du Décret 2016-360  la collectivité impose pour ce marché le mode de transmission des offres par voie électronique notamment via le dispositif MPS permettant de réduire les informations à transmettre. Ce marché fait partie du dispositif \\ marché public simplifié \\ (MPS) dans le cadre du programme national \\ Dites-le-nous une fois \\. La réponse papier ne sera pas acceptée.", 'TRAVAUX', 'SERVICE', 'IDENTITE', 'FAX', 'TEL', 'URL', 'MEL', 'CORRESPONDANT', ' Service marchés publics', 'DENOMINATION', 'RENS_COMPLEMENT', " les candidats doivent choisir un seul mode de transmission de leur offre  soit par voie électronique  soit par le dispositif MPS  sous peine du rejet de l'offre.Pour une remise des offres dématérialisée classique ", " et permet aux entreprises de candidater sur la base de leur seul numéro de SIRET. Le modede transmission des éléments de la candidature et de l'offre est dématérialisé. La réponse électronique est indispensable mais aucune signature n'est exigée (La signature sera dans ce cas demandée a posteriori à la seule entreprise retenue). Voir les détails dans le règlement de la consultation", 'ADRESSES_COMPLEMENTAIRES', 'TYPE', 'DOCUMENTS', 'ELIGIBLE_MPS', 'oui', 'CONDITION_ADMINISTRATIVE', 'REFERENCE_MARCHE', 'FINANCEMENT', 'EPT', 'TYPE_PROCEDURE', 'PROCEDURE_ADAPTE', 'CRITERES_PONDERES', '#text', '@POIDS', ''])

# %%
liste_cle = list(dictio.keys())
for i in range(len(liste_cle)-1,-1,-1):
    if len(liste_cle[i]) >40 or "soit" in liste_cle[i] :
        dictio[liste_cle[i-1]] = dictio[liste_cle[i-1]] + liste_cle[i] +dictio[liste_cle[i]]
        del dictio[liste_cle[i]]

# %%
len(dictio.keys())
# Out:
# 36

# %%
dictio.keys()
# Out:
# dict_keys(['VARIANTES_NON', 'LIEU_EXEC_LIVR', 'VILLE', 'CP', 'ADRESSE', 'OBJET_COMPLET', 'DIV_EN_LOTS', 'NON', 'QUANTITE', 'PRINCIPALES', 'TRAVAUX', 'SERVICE', 'IDENTITE', 'FAX', 'TEL', 'URL', 'MEL', 'CORRESPONDANT', ' Service marchés publics', 'DENOMINATION', 'RENS_COMPLEMENT', 'ADRESSES_COMPLEMENTAIRES', 'TYPE', 'DOCUMENTS', 'ELIGIBLE_MPS', 'oui', 'CONDITION_ADMINISTRATIVE', 'REFERENCE_MARCHE', 'FINANCEMENT', 'EPT', 'TYPE_PROCEDURE', 'PROCEDURE_ADAPTE', 'CRITERES_PONDERES', '#text', '@POIDS', ''])

# %%
dictio
# Out:
# {'VARIANTES_NON': '',
#  'LIEU_EXEC_LIVR': '',
#  'VILLE': 'Pontivy cédex',
#  'CP': '56303',
#  'ADRESSE': '1 Place Ernest Jan - bp96',
#  'OBJET_COMPLET': "Réalisation d'un schéma directeur des systèmes d'information intercommunal",
#  'DIV_EN_LOTS': '',
#  'NON': '',
#  'QUANTITE': "Réalisation d'un schéma directeur des systèmes d'information intercommunal",
#  'PRINCIPALES': "Délai d'exécution  36 mois Variantes non autorisées.Accord-cadre à bons de commande et à tranche optionnelle. Marché à prix mixtes  forfaitaires et unitaires à bons de commande.Pontivy Communauté figurant au titre des pilotes du projet national 100% demat des marchés publics conformément à l'article 40 du Décret 2016-360  la collectivité impose pour ce marché le mode de transmission des offres par voie électronique notamment via le dispositif MPS permettant de réduire les informations à transmettre. Ce marché fait partie du dispositif \\ marché public simplifié \\ (MPS) dans le cadre du programme national \\ Dites-le-nous une fois \\. La réponse papier ne sera pas acceptée.",
#  'TRAVAUX': '',
#  'SERVICE': '',
#  'IDENTITE': '',
#  'FAX': '02-97-25-63-69',
#  'TEL': '02-97-25-01-70',
#  'URL': 'https://marches.e-megalisbretagne.org',
#  'MEL': 'marchespublics@pontivy-communaute.bzh',
#  'CORRESPONDANT': 'Mme BROHAN Laëtitia',
#  ' Service marchés publics': '',
#  'DENOMINATION': 'Site de Mégalis Bretagne avec la référence PI2017-01-02',
#  'RENS_COMPLEMENT': "Le dossier pourra être retiré gratuitement sur la plateforme megalis bretagne en suivant le lien de dématérialisation suivant https://marches.e-megalisbretagne.org/. No de référence attribué au marché à indiquer pour une recherche rapide sur la plateforme Megalis PI2017-01-02Les candidats ont la faculté de présenter leur offre uniquement sous forme dématérialisée classique ou avec le dispositif MPS (avec ou sans signature). Par contre les candidats doivent choisir un seul mode de transmission de leur offre  soit par voie électronique  soit par le dispositif MPS  sous peine du rejet de l'offre.Pour une remise des offres dématérialisée classique utiliser la plateforme mégalis bretagne sous le lien https://marches.emegalisbretagne.org/ et rappeler le no de référence attribué au marché:Pi2017-01-02Ce marché est conforme au dispositif d'expérimentation MPS (Marché Public Simplifié) et permet aux entreprises de candidater sur la base de leur seul numéro de SIRET. Le modede transmission des éléments de la candidature et de l'offre est dématérialisé. La réponse électronique est indispensable mais aucune signature n'est exigée (La signature sera dans ce cas demandée a posteriori à la seule entreprise retenue). Voir les détails dans le règlement de la consultation",
#  'ADRESSES_COMPLEMENTAIRES': '',
#  'TYPE': '',
#  'DOCUMENTS': '',
#  'ELIGIBLE_MPS': '',
#  'oui': '',
#  'CONDITION_ADMINISTRATIVE': '',
#  'REFERENCE_MARCHE': 'PI2017-01-02',
#  'FINANCEMENT': 'Ressouces propres et subventions auxquelles la collectivité peut prétendre',
#  'EPT': '',
#  'TYPE_PROCEDURE': '',
#  'PROCEDURE_ADAPTE': '',
#  'CRITERES_PONDERES': '',
#  '#text': 'Valeur technique',
#  '@POIDS': '40',
#  '': ''}

# %%
try:
    del dictio['#text']
except:
    print('non')

# %%
liste_cle =list(dictio.keys())
for i in range(len(liste_cle)-1,-1,-1):
    if liste_cle[i].upper() != liste_cle[i]:
        print(liste_cle[i])
        dictio[liste_cle[i-1]] += liste_cle[i]
        del dictio[liste_cle[i]]
# Out:
# oui
#  Service marchés publics

# %%
liste_cle =list(dictio.keys())
for k in liste_cle:
    if dictio[k]=='':
        del dictio[k]

# %%
dictio.keys()
# Out:
# dict_keys(['VILLE', 'CP', 'ADRESSE', 'OBJET_COMPLET', 'QUANTITE', 'PRINCIPALES', 'FAX', 'TEL', 'URL', 'MEL', 'CORRESPONDANT', 'DENOMINATION', 'RENS_COMPLEMENT', 'ELIGIBLE_MPS', 'REFERENCE_MARCHE', 'FINANCEMENT', '@POIDS'])

# %%
dictio
# Out:
# {'VILLE': 'Pontivy cédex',
#  'CP': '56303',
#  'ADRESSE': '1 Place Ernest Jan - bp96',
#  'OBJET_COMPLET': "Réalisation d'un schéma directeur des systèmes d'information intercommunal",
#  'QUANTITE': "Réalisation d'un schéma directeur des systèmes d'information intercommunal",
#  'PRINCIPALES': "Délai d'exécution  36 mois Variantes non autorisées.Accord-cadre à bons de commande et à tranche optionnelle. Marché à prix mixtes  forfaitaires et unitaires à bons de commande.Pontivy Communauté figurant au titre des pilotes du projet national 100% demat des marchés publics conformément à l'article 40 du Décret 2016-360  la collectivité impose pour ce marché le mode de transmission des offres par voie électronique notamment via le dispositif MPS permettant de réduire les informations à transmettre. Ce marché fait partie du dispositif \\ marché public simplifié \\ (MPS) dans le cadre du programme national \\ Dites-le-nous une fois \\. La réponse papier ne sera pas acceptée.",
#  'FAX': '02-97-25-63-69',
#  'TEL': '02-97-25-01-70',
#  'URL': 'https://marches.e-megalisbretagne.org',
#  'MEL': 'marchespublics@pontivy-communaute.bzh',
#  'CORRESPONDANT': 'Mme BROHAN Laëtitia Service marchés publics',
#  'DENOMINATION': 'Site de Mégalis Bretagne avec la référence PI2017-01-02',
#  'RENS_COMPLEMENT': "Le dossier pourra être retiré gratuitement sur la plateforme megalis bretagne en suivant le lien de dématérialisation suivant https://marches.e-megalisbretagne.org/. No de référence attribué au marché à indiquer pour une recherche rapide sur la plateforme Megalis PI2017-01-02Les candidats ont la faculté de présenter leur offre uniquement sous forme dématérialisée classique ou avec le dispositif MPS (avec ou sans signature). Par contre les candidats doivent choisir un seul mode de transmission de leur offre  soit par voie électronique  soit par le dispositif MPS  sous peine du rejet de l'offre.Pour une remise des offres dématérialisée classique utiliser la plateforme mégalis bretagne sous le lien https://marches.emegalisbretagne.org/ et rappeler le no de référence attribué au marché:Pi2017-01-02Ce marché est conforme au dispositif d'expérimentation MPS (Marché Public Simplifié) et permet aux entreprises de candidater sur la base de leur seul numéro de SIRET. Le modede transmission des éléments de la candidature et de l'offre est dématérialisé. La réponse électronique est indispensable mais aucune signature n'est exigée (La signature sera dans ce cas demandée a posteriori à la seule entreprise retenue). Voir les détails dans le règlement de la consultation",
#  'ELIGIBLE_MPS': 'oui',
#  'REFERENCE_MARCHE': 'PI2017-01-02',
#  'FINANCEMENT': 'Ressouces propres et subventions auxquelles la collectivité peut prétendre',
#  '@POIDS': '40'}
